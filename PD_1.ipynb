# %% [markdown]
# Задание 1
#
# Скачайте с сайта grouplens.org...movielens/ датасет любого размера.
#
# Определите, какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd

# %%
mv = pd.read_csv('movies.csv')
mv.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
rt = pd.read_csv('ratings.csv')
rt.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
# Объединил 2 csv обычным джойном

mv_rt = mv.merge(rt, how='inner')
mv_rt
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
#  Сделал сначала сортировку по рейтингу, сбросил индексы, затем к колонке title применил подсчет количества и получил первый title фильма

mv_rt[mv_rt.rating == 5.0].reset_index()['title'].value_counts().head(1)
# Out:
# Shawshank Redemption, The (1994)    153
# Name: title, dtype: int64

# %% [markdown]
# Задание 2
#
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года.
#
# Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country    year  quantity  category
# 0  Austria  1996.0       5.0       1.0
# 1  Austria  1995.0      17.0       1.0
# 2  Belgium  2014.0       0.0       1.0
# 3  Belgium  2013.0       0.0       1.0
# 4  Belgium  2012.0      35.0       1.0

# %%
power['country'].unique()
# Out:
# array(['Austria', 'Belgium', 'Czechia', 'Finland', 'France', 'Greece',
#        'Hungary', 'Italy', 'Korea, Republic of', 'Netherlands', 'Romania',
#        'Serbia', 'Slovakia', 'Ukraine', 'United Kingdom', 'United States',
#        'Brunei Darussalam', 'Bulgaria', 'Canada', 'Chile', 'Croatia',
#        'Iran (Islamic Rep. of)', 'Jordan', 'Lithuania', 'Mexico', 'Oman',
#        'Other Asia', 'Poland', 'Portugal', 'Spain', 'Sweden',
#        'Switzerland', 'T.F.Yug.Rep. Macedonia', 'Turkey', 'Uzbekistan',
#        'Argentina', 'Colombia', 'Germany', 'Norway', 'Australia',
#        'China, Macao SAR', 'Japan', 'Denmark', 'Ireland', 'Philippines',
#        'Bangladesh', 'Eritrea', 'Ethiopia', 'Lesotho', 'Nepal', 'Niger',
#        'Pakistan', 'Serbia and Montenegro', 'Tunisia', 'Botswana',
#        'Georgia', 'Republic of Moldova', 'Peru', 'South Africa',
#        'Iceland', 'Latvia', 'Luxembourg', 'Cuba', 'Kyrgyzstan',
# ...

# %%
# Фильтрую страны
filtered_country = power[(power['country'] == 'Estonia') | (power['country'] == 'Latvia') | (power['country'] == 'Lithuania')]
filtered_country
# Out:
#           country    year  quantity  category
# 373     Lithuania  2014.0      39.0       1.0
# 374     Lithuania  2013.0     192.0       1.0
# 375     Lithuania  2012.0     196.0       1.0
# 376     Lithuania  2011.0     171.0       1.0
# 377     Lithuania  2010.0     158.0       1.0
# ...           ...     ...       ...       ...
# 175436  Lithuania  1996.0    3767.0      18.0
# 175437  Lithuania  1995.0    3181.0      18.0
# 175438  Lithuania  1994.0    3585.0      18.0
# 175439  Lithuania  1993.0    5161.0      18.0
# 175440  Lithuania  1992.0    4070.0      18.0
#
# [2846 rows x 4 columns]

# %%
# Фильтрую категории
filtered_country_category = filtered_country[ (filtered_country['category'] == 4) | (filtered_country['category'] == 12) | (filtered_country['category'] == 21)]
filtered_country_category
# Out:
#           country    year  quantity  category
# 10617     Estonia  2008.0       1.0       4.0
# 10618     Estonia  2007.0       0.0       4.0
# 10619     Estonia  2006.0       0.0       4.0
# 10620     Estonia  2005.0       1.0       4.0
# 10621     Estonia  2004.0       1.0       4.0
# ...           ...     ...       ...       ...
# 121177  Lithuania  2011.0       4.0      12.0
# 121178  Lithuania  2010.0       3.0      12.0
# 121179  Lithuania  2009.0       2.0      12.0
# 121180  Lithuania  2008.0       4.0      12.0
# 121181  Lithuania  2007.0       6.0      12.0
#
# [389 rows x 4 columns]

# %%
# Фильтрую года и quantity, проверяю что бы не было отрицательных значений сортировкой
filtered_country_category_year = filtered_country_category[ (filtered_country_category['year'] >= 2004) & (filtered_country_category['year'] <= 2010) ]
filtered_country_category_year = filtered_country_category_year[ (filtered_country_category_year['quantity'] >= 0 ) ]
filtered_country_category_year.sort_values('quantity')
# Out:
#           country    year  quantity  category
# 16069   Lithuania  2007.0       0.0       4.0
# 14648      Latvia  2009.0       0.0       4.0
# 14649      Latvia  2008.0       0.0       4.0
# 14650      Latvia  2007.0       0.0       4.0
# 26468      Latvia  2008.0       0.0       4.0
# ...           ...     ...       ...       ...
# 114108  Lithuania  2008.0     351.0      12.0
# 114109  Lithuania  2007.0     361.0      12.0
# 113241  Lithuania  2007.0     369.0      12.0
# 112244  Lithuania  2007.0     369.0      12.0
# 116898  Lithuania  2007.0     378.0      12.0
#
# [174 rows x 4 columns]

# %% [markdown]
# Задание 3
#
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
#
# Примеры страниц (необязательно брать именно эти):
#
# https://fortrader.org/quotes
#
# www.finanz.ru...om-vremeni

# %%
site = pd.read_html('https://www.finanz.ru/valyuty/v-realnom-vremeni', attrs={'class': 'quote_list'} , encoding='UTF-8')
site
# Out:
# [    Unnamed: 0              Рубль  Предложение  Спрос  Предыдущее закрытие  \
#  0          NaN            GBP/RUB      1179917      -              1243930
#  1          NaN            EUR/RUB      1446655      -              1446655
#  2          NaN            USD/RUB       901250      -               950000
#  3          NaN            JPY/RUB        07293      -                07668
#  4          NaN            CNY/RUB       140657      -               149085
#  5          NaN            CHF/RUB       962874      -              1016478
#  6          NaN               Евро  Предложение  Спрос  Предыдущее закрытие
#  7          NaN            EUR/USD        10995      -                10988
#  8          NaN            EUR/GBP        08398      -                08393
#  9          NaN            EUR/JPY      1358625      -              1361100
#  10         NaN            EUR/CHF        10293      -                10269
# ...
